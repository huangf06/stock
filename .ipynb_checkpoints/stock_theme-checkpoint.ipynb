# %%
import pandas as pd
import numpy as np
import tushare as ts
import time

# %%
ts.set_token('7122fa9fc9317803d678bcdf5cbc2d2f67174243855d87eb36b48c57')
pro=ts.pro_api()
dt=time.strftime('%Y%m%d',time.localtime())

# %%
dc = pro.concept()

# %%
df=pd.DataFrame(columns=['id', 'concept_name', 'ts_code', 'name'])
for i in dc.code:
    da=pro.concept_detail(id=i)
    df=df.append(da,ignore_index=True)

# %%
df.to_csv('stock_concept.csv',index=False,encoding='gbk')

# %%
da=pro.concept_detail(id='TS358')

# %%
dc
# Out:
#       code        name src
# 0      TS0        密集调研  ts
# 1      TS1       南北船合并  ts
# 2      TS2          5G  ts
# 3      TS3          机场  ts
# 4      TS4         高价股  ts
# 5      TS5          烧碱  ts
# 6      TS6       AH溢价股  ts
# 7      TS7          保险  ts
# 8      TS8         PVC  ts
# 9      TS9          啤酒  ts
# 10    TS10          火电  ts
# 11    TS11          银行  ts
# 12    TS12         碳纤维  ts
# 13    TS13         安邦系  ts
# 14    TS14         特高压  ts
# 15    TS15         高股息  ts
# 16    TS16         光通信  ts
# 17    TS17         草甘膦  ts
# 18    TS18        高速公路  ts
# 19    TS19        有色-铝  ts
# 20    TS20        有色-锆  ts
# 21    TS21        主题公园  ts
# 22    TS22         白马股  ts
# 23    TS23       雄安-地产  ts
# 24    TS24        OLED  ts
# 25    TS25        MSCI  ts
# 26    TS26        健康中国  ts
# 27    TS27       养老金持股  ts
# 28    TS28          水电  ts
# 29    TS29        环氧丙烷  ts
# ..     ...         ...  ..
# 329  TS329          广电  ts
# 330  TS330  深圳本地股/深汕合作  ts
# 331  TS331         化妆品  ts
# 332  TS332        体育产业  ts
# 333  TS333          影视  ts
# 334  TS334         壳公司  ts
# 335  TS335          黄金  ts
# 336  TS336          海南  ts
# 337  TS337        知识产权  ts
# 338  TS338        燃料乙醇  ts
# 339  TS339        ST摘帽  ts
# 340  TS340        破发次新  ts
# 341  TS341     上海自由贸易港  ts
# 342  TS342          民航  ts
# 343  TS343          宁夏  ts
# 344  TS344        人脸识别  ts
# 345  TS345       强势人气股  ts
# 346  TS346          橡胶  ts
# 347  TS347          动漫  ts
# 348  TS348        苹果期货  ts
# 349  TS349        无人银行  ts
# 350  TS350         富勒烯  ts
# 351  TS351      科创板概念股  ts
# 352  TS352          创投  ts
# 353  TS353        电子车牌  ts
# 354  TS354       雄安-设计  ts
# 355  TS355        工业大麻  ts
# 356  TS356        透明工厂  ts
# 357  TS357         人造肉  ts
# 358  TS358        垃圾分类  ts
#
# [359 rows x 3 columns]
