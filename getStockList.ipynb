# %%
import pandas as pd, numpy as np, tushare as ts
import time

# %%
ts.set_token('7122fa9fc9317803d678bcdf5cbc2d2f67174243855d87eb36b48c57')
pro=ts.pro_api()

# %%
data = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,fullname,market,exchange,list_date,is_hs')
# data.to_csv('StockList.csv',encoding='gbk',index=False)

# %%
# stk_d3s=data[data.area.isin(['黑龙江','吉林','辽宁'])]
# stk_d3s.to_csv('StockinD3S.csv',encoding='gbk',index=False)

# %%
dt=time.strftime('%Y%m%d',time.localtime())
df = pro.daily(trade_date=dt)

# %%
# 涨停板
zt=df[df.pct_chg>9.9].reset_index(drop=True)
# 一字涨停板
zt1=zt[zt.high==zt.low]
# 开盘没涨停的涨停板
zt2=zt[zt.open<zt.high]
# 涨停被砸
zt3=df[(df.high>1.099*df.pre_close)&(df.close<df.high)].reset_index(drop=True)

# %%
zt3
# Out:
#       ts_code trade_date   open   high    low  close  pre_close  change  \
# 0   002124.SZ   20190717  15.39  16.68  15.21  16.11      15.16    0.95
# 1   603002.SH   20190717   4.01   4.40   3.98   4.27       4.00    0.27
# 2   002185.SZ   20190717   4.42   4.87   4.40   4.69       4.43    0.26
# 3   002753.SZ   20190717   8.73   9.60   8.73   9.21       8.73    0.48
# 4   300480.SZ   20190717  13.55  14.89  13.54  14.19      13.54    0.65
# 5   000880.SZ   20190717   8.29   9.08   8.25   8.61       8.25    0.36
# 6   002225.SZ   20190717   5.39   5.96   5.26   5.31       5.42   -0.11
# 7   000859.SZ   20190717   5.20   5.76   5.16   5.46       5.24    0.22
# 8   000150.SZ   20190717   5.55   5.82   5.45   5.65       5.29    0.36
# 9   000603.SZ   20190717  11.20  11.77  11.20  11.73      10.70    1.03
# 10  603982.SH   20190717  20.20  22.34  20.02  22.00      20.31    1.69
# 11  002716.SZ   20190717   7.18   7.36   6.95   7.02       6.69    0.33
# ...
